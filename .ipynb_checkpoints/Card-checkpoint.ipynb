# %% [markdown]
# ### Import lib

# %%
import jupyter_dash
import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd

# %%
app = jupyter_dash.JupyterDash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# %% [markdown]
# ### Load data

# %%
df = px.data.gapminder()
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %% [markdown]
# ### Cards

# %%
card_main = dbc.Card(
    [
        dbc.CardImg(src="image/ball_of_fire.jpg", top=True, bottom=False,
                    title="Image by Kevin Dinkel", alt='Learn Dash Bootstrap Card Component'),
        dbc.CardBody(
            [
                html.H4("Learn Dash with Charming Data", className="card-title"),
                html.H6("Lesson 1:", className="card-subtitle"),
                html.P(
                    "Choose the year you would like to see on the bubble chart.",
                    className="card-text",
                ),
                dcc.Dropdown(id='user_choice', options=[{'label': yr, "value": yr} for yr in df.year.unique()],
                             value=2007, clearable=False, style={"color": "#000000"}),
                # dbc.Button("Press me", color="primary"),
                # dbc.CardLink("GirlsWhoCode", href="https://girlswhocode.com/", target="_blank"),
            ]
        ),
    ],
    color="dark",   # https://bootswatch.com/default/ for more card colors
    inverse=True,   # change color of text (black or white)
    outline=False,  # True = remove the block colors from the background and header
)

card_question = dbc.Card(
    [
        dbc.CardBody([
            html.H4("Question 1", className="card-title"),
            html.P("What was India's life expectancy in 1952?", className="card-text"),
            dbc.ListGroup(
                [
                    dbc.ListGroupItem("A. 55 years"),
                    dbc.ListGroupItem("B. 37 years"),
                    dbc.ListGroupItem("C. 49 years"),
                ], flush=True)
        ]),
    ], color="warning",
)

card_graph = dbc.Card(
        dcc.Graph(id='my_bar', figure={}), body=True, color="secondary",
)

# %% [markdown]
# ### Layout

# %%
app.layout = html.Div([
    dbc.Row([dbc.Col(card_main, width=3),
             dbc.Col(card_question, width=3),
             dbc.Col(card_graph, width=5)], justify="around"),  # justify="start", "center", "end", "between", "around"

#     dbc.CardGroup([card_main, card_question, card_graph]),   # attaches cards with equal width and height columns
#     dbc.CardDeck([card_main, card_question, card_graph]),    # same as CardGroup but with gutter in between cards

#     dbc.CardColumns([                        # Cards organised into Masonry-like columns
#             card_main,
#             card_question,
#             card_graph,
#             card_question,
#             card_question,
#     ])

])

# %% [markdown]
# ### Callback

# %%
@app.callback(
    Output("my_bar", "figure"),
    [Input("user_choice", "value")]
)
def update_graph(value):
    fig = px.scatter(df.query("year=={}".format(str(value))), x="gdpPercap", y="lifeExp",
                     size="pop", color="continent", title=str(value),
                     hover_name="country", log_x=True, size_max=60).update_layout(showlegend=True, title_x=0.5)
    return fig

# %%
app.run_server(mode='inline')
# Out:
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_shutdown_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_shutdown_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62718, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
#
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62721, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
#
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62724, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
#
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62727, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62730, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
#
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62733, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62736, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62739, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
# ...
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62761, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
# ---------------------------------------------------------------------------
# DuplicateIdError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\flask\app.py in wsgi_app(
#     self=<Flask '__main__'>,
#     environ={'HTTP_ACCEPT': '*/*', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8050', 'HTTP_USER_AGENT': 'python-requests/2.24.0', 'PATH_INFO': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'QUERY_STRING': '', 'RAW_URI': '/_alive_b49b3815-3ba4-4d7c-a77a-7f1170ccddd8', 'REMOTE_ADDR': '127.0.0.1', 'REMOTE_PORT': 62764, ...},
#     start_response=<function WSGIRequestHandler.run_wsgi.<locals>.start_response>
# )
#    2445             try:
#    2446                 ctx.push()
# -> 2447                 response = self.full_dispatch_request()
#         response = undefined
#         self.full_dispatch_request = <bound method Flask.full_dispatch_request of <Flask '__main__'>>
#    2448             except Exception as e:
#    2449                 error = e
#
# ~\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1943         .. versionadded:: 0.7
#    1944         """
# -> 1945         self.try_trigger_before_first_request_functions()
#         self.try_trigger_before_first_request_functions = <bound method Flask.try_trigger_before_first_request_functions of <Flask '__main__'>>
#    1946         try:
#    1947             request_started.send(self)
#
# ~\anaconda3\lib\site-packages\flask\app.py in try_trigger_before_first_request_functions(self=<Flask '__main__'>)
#    1991                 return
#    1992             for func in self.before_first_request_funcs:
# -> 1993                 func()
#         func = <bound method Dash._setup_server of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1994             self._got_first_request = True
#    1995
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\dash.py in _setup_server(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#    1074             self._walk_assets_directory()
#    1075
# -> 1076         _validate.validate_layout(self.layout, self._layout_value())
#         global _validate.validate_layout = <function validate_layout at 0x00000151DEAE3E50>
#         self.layout = Div([Row(children=[Col(children=Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), width=3), Col(children=Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), width=3), Col(children=Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True), width=5)], justify='around'), CardGroup([Card(children=[CardImg(top=True, bottom=False, src='image/ball_of_fire.jpg', alt='Learn Dash Bootstrap Card Component', title='Image by Kevin Dinkel'), CardBody([H4(children='Learn Dash with Charming Data', className='card-title'), H6(children='Lesson 1:', className='card-subtitle'), P(children='Choose the year you would like to see on the bubble chart.', className='card-text'), Dropdown(id='user_choice', options=[{'label': 1952, 'value': 1952}, {'label': 1957, 'value': 1957}, {'label': 1962, 'value': 1962}, {'label': 1967, 'value': 1967}, {'label': 1972, 'value': 1972}, {'label': 1977, 'value': 1977}, {'label': 1982, 'value': 1982}, {'label': 1987, 'value': 1987}, {'label': 1992, 'value': 1992}, {'label': 1997, 'value': 1997}, {'label': 2002, 'value': 2002}, {'label': 2007, 'value': 2007}], value=2007, clearable=False, style={'color': '#000000'})])], color='dark', outline=False, inverse=True), Card(children=[CardBody([H4(children='Question 1', className='card-title'), P(children="What was India's life expectancy in 1952?", className='card-text'), ListGroup(children=[ListGroupItem('A. 55 years'), ListGroupItem('B. 37 years'), ListGroupItem('C. 49 years')], flush=True)])], color='warning'), Card(children=Graph(id='my_bar', figure={}), color='secondary', body=True)])])
#         self._layout_value = <bound method Dash._layout_value of <jupyter_dash.jupyter_app.JupyterDash object at 0x00000151F75AD400>>
#    1077
#    1078         self._generate_scripts_html()
#
# ~\AppData\Roaming\Python\Python38\site-packages\dash\_validate.py in validate_layout(
#     layout=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])]),
#     layout_value=Div([Row(children=[Col(children=Card(children=[C...r', figure={}), color='secondary', body=True)])])
# )
#     346         component_id = stringify_id(getattr(component, "id", None))
#     347         if component_id and component_id in component_ids:
# --> 348             raise exceptions.DuplicateIdError(
#         global exceptions.DuplicateIdError.format = undefined
#         component_id = 'user_choice'
#     349                 """
#     350                 Duplicate component id found in the initial layout: `{}`
#
# DuplicateIdError: Duplicate component id found in the initial layout: `user_choice`
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-fb925e3b1d8e> in <module>
# ----> 1 app.run_server(mode='inline')
#
# ~\anaconda3\lib\site-packages\jupyter_dash\jupyter_app.py in run_server(self, mode, width, height, inline_exceptions, **kwargs)
#     317                 )
#     318
# --> 319         wait_for_app()
#     320
#     321         if JupyterDash._in_colab:
#
# ~\AppData\Roaming\Python\Python38\site-packages\retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# ~\AppData\Roaming\Python\Python38\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     210                 if not self._wrap_exception and attempt.has_exception:
#     211                     # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 212                     raise attempt.get()
#     213                 else:
#     214                     raise RetryError(attempt)
#
# ~\AppData\Roaming\Python\Python38\site-packages\retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# ~\anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~\AppData\Roaming\Python\Python38\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# ~\anaconda3\lib\site-packages\jupyter_dash\jupyter_app.py in wait_for_app()
#     310                     host=host, port=port, token=JupyterDash._token
#     311                 )
# --> 312                 raise OSError(
#     313                     "Address '{url}' already in use.\n"
#     314                     "    Try passing a different port to run_server.".format(
#
# OSError: Address 'http://127.0.0.1:8050' already in use.
#     Try passing a different port to run_server.
