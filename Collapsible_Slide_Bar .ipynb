# %%
"""
This app creates a simple sidebar layout using inline style arguments and the
dbc.Nav component.

dcc.Location is used to track the current location. There are two callbacks,
one uses the current location to render the appropriate page content, the other
uses the current location to toggle the "active" properties of the navigation
links.

For more details on building multi-page Dash applications, check out the Dash
documentation: https://dash.plot.ly/urls
"""
import dash
import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State

# %%
app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])

# %%
# the style arguments for the sidebar. We use position:fixed and a fixed width
SIDEBAR_STYLE = {
    "position": "fixed",
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "16rem",
    "padding": "2rem 1rem",
    "background-color": "#f8f9fa",
}

# the styles for the main content position it to the right of the sidebar and
# add some padding.
CONTENT_STYLE = {
    "margin-left": "18rem",
    "margin-right": "2rem",
    "padding": "1rem 1rem",
}
button = html.Div(
    [
        dbc.Button("Collapse",id="sidebar-toggle", color="primary", className="mr-1")
    ],
    style = {
        "position": "fixed",
        "z-index": "1",
    }
)
collapse = dbc.Collapse(
    [
        html.H2("Sidebar", className="display-4"),
        html.Hr(),
        html.P(
            "A simple sidebar layout with navigation links", className="lead"
        ),
        dbc.Nav(
            [
                dbc.NavLink("Page 1", href="/page-1", id="page-1-link"),
                dbc.NavLink("Page 2", href="/page-2", id="page-2-link"),
                dbc.NavLink("Page 3", href="/page-3", id="page-3-link"),
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style=SIDEBAR_STYLE,
    id="collapse",
    is_open=True,
)

sidebar = html.Div([button, collapse])

content = html.Div(id="page-content", style=CONTENT_STYLE)

app.layout = html.Div([dcc.Location(id="url"), sidebar, content])


# this callback uses the current pathname to set the active state of the
# corresponding nav link to true, allowing users to tell see page they are on
@app.callback(
    [Output(f"page-{i}-link", "active") for i in range(1, 4)],
    [Input("url", "pathname")],
)
def toggle_active_links(pathname):
    if pathname == "/":
        # Treat page 1 as the homepage / index
        return True, False, False
    return [pathname == f"/page-{i}" for i in range(1, 4)]


@app.callback(Output("page-content", "children"), [Input("url", "pathname")])
def render_page_content(pathname):
    if pathname in ["/", "/page-1"]:
        return html.P("This is the content of page 1!")
    elif pathname == "/page-2":
        return html.P("This is the content of page 2. Yay!")
    elif pathname == "/page-3":
        return html.P("Oh cool, this is page 3!")
    # If the user tries to reach a different page, return a 404 message
    return dbc.Jumbotron(
        [
            html.H1("404: Not found", className="text-danger"),
            html.Hr(),
            html.P(f"The pathname {pathname} was not recognised..."),
        ]
    )

@app.callback(
    Output("collapse", "is_open"),
    [Input("sidebar-toggle", "n_clicks")],
    [State("collapse", "is_open")],
)
def toggle_collapse(n, is_open):
    if n:
        return not is_open
    return is_open

# %%
if __name__ == "__main__":
    app.run_server(port=8086)
# Out:
# Dash is running on http://127.0.0.1:8086/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8086/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Sep/2020 13:06:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:18] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:18] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:06:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:22:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:22:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:23:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:23:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:23:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:39:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:39:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:39:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:39:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:39:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:39:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Sep/2020 13:39:44] "POST /_dash-update-component HTTP/1.1" 200 -
